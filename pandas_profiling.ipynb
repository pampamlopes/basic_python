# %% [markdown]
# <a href="https://colab.research.google.com/github/pampamlopes/basic_python/blob/main/pandas_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset: Rain in Australia
#
# link: https://www.kaggle.com/jsphyg/weather-dataset-rattle-package

# %%
import pandas as pd

# %%
df = pd.read_csv('weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  ...  Temp3pm  RainToday  RainTomorrow
# 0  2008-12-01   Albury     13.4  ...     21.8         No            No
# 1  2008-12-02   Albury      7.4  ...     24.3         No            No
# 2  2008-12-03   Albury     12.9  ...     23.2         No            No
# 3  2008-12-04   Albury      9.2  ...     26.5         No            No
# 4  2008-12-05   Albury     17.5  ...     29.7         No            No
#
# [5 rows x 23 columns]

# %%
# !pip install -U pandas-profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df)

# %%
profile.to_notebook_iframe()

# %%
profile.to_file("Dados.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.dropna(subset=['RainTomorrow','RainToday'], inplace=True)

# %%
print(df['RainTomorrow'].isnull().sum())
print(df['RainToday'].isnull().sum())
# Out:
# 0
# 0

# %%
profile = ProfileReport(df)
profile.to_file("dados2.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
